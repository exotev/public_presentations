# %% [markdown]
# # Presentation EXOTEV 2025-04-07
#
# ![image.png](attachment:image.png)
#
# Copyright (c) 2025. [EXOTEV Technologies](http://www.exotev.com)

# %%
import numpy as np
import pandas as pd

# %%
cities_df = pd.read_csv("villes_MR.csv", sep='\t')

# %%
cities_df
# Out:
#     Rank             Ville        مدينة Population_1977 Population_1988  \
# 0      1       Nouakchott     انواكشوط          138530          393325
# 1      2       Nouadhibou     انواديبو           22365           59198
# 2      3            Rosso         روصو           15888           27783
# 3      4      Adel Bagrou                         2199            6020
# 4      5            Boghé         بوكى            7891           12557
# 5      6            Kiffa         كيفة           10703           29292
# 6      7          Zouérat      ازويرات           17947           25892
# 7      8              édi       كيهيدي           20356           30515
# 8      9       Boû Gâdoûm
# 9     10       Boutilimit      بوتلميت            7263           14545
# 10    11             Atâr         أطار           16394           21366
# 11    12          Bareine
# 12    13           Ghabou
# 13    14           Hamoud
# 14    15              Mâl
# 15    16          N'Beike
# ...

# %%
cities_df['Population_1977'] = pd.to_numeric(cities_df['Population_1977'], errors='coerce')
cities_df['Population_1988'] = pd.to_numeric(cities_df['Population_1988'], errors='coerce')
cities_df['Population_2000'] = pd.to_numeric(cities_df['Population_2000'], errors='coerce')
cities_df['Population_2005'] = pd.to_numeric(cities_df['Population_2005'], errors='coerce')

# %%
cities_df.plot.bar(x='Ville', y=['Population_1977', 'Population_1988', 'Population_2000', 'Population_2005'], figsize=(16,16))
# Out:
# <Axes: xlabel='Ville'>

# %%
"".join(cities_df.Ville)
# Out:
# "Nouakchott Nouadhibou Rosso Adel Bagrou Boghé Kiffa Zouérat édi Boû Gâdoûm Boutilimit Atâr Bareine Ghabou Hamoud Mâl N'Beike Gouraye Timbédra Magta Lahjar Guérou Soudoud Sélibaby Voum Legleite Legceïba Boû Steïlé Sangrave Tintane Néma Aleg Tidjikja Walata Ayoûn el-Atroûs Bababé Aqjawajat Chagar "
